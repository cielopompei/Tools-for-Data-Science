# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **María Cielo Pompei**

# %% [markdown]
# Project Engineer | Chemical Engineering

# %% [markdown]
# *I'm interested in Data Science because I believe that there is a lot of information to be discover behind the Data Sets and this information could improve lot of situations.*

# %% [markdown]
# ### The following Code will print the result of the sum 1+1

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# - Sugar
# - Salt
# - Meat
# - Tomato
# - Lettuce

# %% [markdown]
# | Item | Quantity | Unit Price | Total Price |
# | ----| ----| ----| ----|
# | Candy | 10 | USD 0.50 | USD 5.00 |
# | Chocolate | 2 | USD 3.00 | USD 6.00 |
# | Lollipop | 5 | USD 1.00 | USD 5.00 |

# %% [markdown]
# https://www.linkedin.com/in/maria-cielo-pompei/
